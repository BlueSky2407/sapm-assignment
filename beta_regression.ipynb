# %%
import pandas as pd
from statsmodels.regression.linear_model import OLS

# %%
Rf = 0.0633

# %%
data = pd.read_csv('data/returns.csv')

instrs = ["OLAELEC","WHIRLPOOL","SAGILITY","RAMCOCEM","TATACHEM"]
Rm_Rf = data["INDEX"] - Rf
betas = {}

for instr in instrs:
    model = OLS(data[instr]-Rf, Rm_Rf).fit()
    betas[instr] = model.params[0]
    print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                OLAELEC   R-squared (uncentered):                   0.789
# Model:                            OLS   Adj. R-squared (uncentered):              0.788
# Method:                 Least Squares   F-statistic:                              838.9
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):                    7.45e-78
# Time:                        20:27:32   Log-Likelihood:                          438.26
# No. Observations:                 226   AIC:                                     -874.5
# Df Residuals:                     225   BIC:                                     -871.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# INDEX          1.0386      0.036     28.963      0.000       0.968       1.109
# ==============================================================================
# Omnibus:                      109.498   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              615.929
# Skew:                           1.847   Prob(JB):                    1.79e-134
# Kurtosis:                      10.195   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              WHIRLPOOL   R-squared (uncentered):                   0.869
# Model:                            OLS   Adj. R-squared (uncentered):              0.869
# Method:                 Least Squares   F-statistic:                              1494.
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):                   2.56e-101
# Time:                        20:27:32   Log-Likelihood:                          508.70
# No. Observations:                 226   AIC:                                     -1015.
# Df Residuals:                     225   BIC:                                     -1012.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# INDEX          1.0149      0.026     38.652      0.000       0.963       1.067
# ==============================================================================
# Omnibus:                      197.250   Durbin-Watson:                   1.653
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7055.380
# Skew:                          -3.052   Prob(JB):                         0.00
# Kurtosis:                      29.683   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               SAGILITY   R-squared (uncentered):                   0.859
# Model:                            OLS   Adj. R-squared (uncentered):              0.858
# Method:                 Least Squares   F-statistic:                              1366.
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):                    1.58e-97
# Time:                        20:27:32   Log-Likelihood:                          508.82
# No. Observations:                 226   AIC:                                     -1016.
# Df Residuals:                     225   BIC:                                     -1012.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# INDEX          0.9698      0.026     36.956      0.000       0.918       1.021
# ==============================================================================
# Omnibus:                       21.774   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.622
# Skew:                           0.670   Prob(JB):                     1.00e-06
# Kurtosis:                       4.066   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               RAMCOCEM   R-squared (uncentered):                   0.948
# Model:                            OLS   Adj. R-squared (uncentered):              0.948
# Method:                 Least Squares   F-statistic:                              4117.
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):                   1.30e-146
# Time:                        20:27:32   Log-Likelihood:                          631.83
# No. Observations:                 226   AIC:                                     -1262.
# Df Residuals:                     225   BIC:                                     -1258.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# INDEX          0.9771      0.015     64.166      0.000       0.947       1.007
# ==============================================================================
# Omnibus:                        6.626   Durbin-Watson:                   1.834
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                7.375
# Skew:                           0.272   Prob(JB):                       0.0250
# Kurtosis:                       3.697   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               TATACHEM   R-squared (uncentered):                   0.970
# Model:                            OLS   Adj. R-squared (uncentered):              0.970
# Method:                 Least Squares   F-statistic:                              7270.
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):                   2.74e-173
# Time:                        20:27:32   Log-Likelihood:                          689.96
# No. Observations:                 226   AIC:                                     -1378.
# Df Residuals:                     225   BIC:                                     -1375.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# INDEX          1.0039      0.012     85.267      0.000       0.981       1.027
# ==============================================================================
# Omnibus:                       33.309   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.591
# Skew:                           0.622   Prob(JB):                     2.13e-20
# Kurtosis:                       5.842   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\adity\AppData\Local\Temp\ipykernel_13240\3397885016.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   betas[instr] = model.params[0]
# C:\Users\adity\AppData\Local\Temp\ipykernel_13240\3397885016.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   betas[instr] = model.params[0]
# C:\Users\adity\AppData\Local\Temp\ipykernel_13240\3397885016.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   betas[instr] = model.params[0]
# C:\Users\adity\AppData\Local\Temp\ipykernel_13240\3397885016.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   betas[instr] = model.params[0]
# C:\Users\adity\AppData\Local\Temp\ipykernel_13240\3397885016.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   betas[instr] = model.params[0]

# %%
betas
# Out:
# {'OLAELEC': np.float64(1.0385878760279408),
#  'WHIRLPOOL': np.float64(1.014850957433697),
#  'SAGILITY': np.float64(0.9697822406376782),
#  'RAMCOCEM': np.float64(0.9770651190907458),
#  'TATACHEM': np.float64(1.0038750682146738)}
